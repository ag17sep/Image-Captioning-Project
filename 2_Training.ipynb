# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, I train the CNN-RNN model.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, I customized the training of the CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.
#
# ### Task #1
#
# I had the following hyperparameters to tune :
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.
# - `save_every` - determines how often to save the model weights. This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# I used the values of the hyperparameters from thi paper [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!

# %%
import nltk
# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Animesh
# [nltk_data]     Garg\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# UsageError: Line magic function `%` not found.

# %%
import torch
import torch.nn as nn
from torchvision import transforms
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 32          # batch size
vocab_threshold = 6        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 20             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params, lr=0.001, betas=(0.9, 0.999), eps = 1e-08)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.47s)
# creating index...
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:01<00:00, 6781.48it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.

# %%
import torch.utils.data as data
import numpy as np
import os

# Open the training log file.
f = open(log_file, 'w')
    
for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.contiguous().view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/20], Step [100/12942], Loss: 4.0098, Perplexity: 55.13363
# Epoch [1/20], Step [200/12942], Loss: 3.9487, Perplexity: 51.8688
# Epoch [1/20], Step [300/12942], Loss: 3.8446, Perplexity: 46.7402
# Epoch [1/20], Step [400/12942], Loss: 3.2975, Perplexity: 27.0458
# Epoch [1/20], Step [500/12942], Loss: 3.2526, Perplexity: 25.8578
# Epoch [1/20], Step [600/12942], Loss: 3.1154, Perplexity: 22.5429
# Epoch [1/20], Step [700/12942], Loss: 3.2954, Perplexity: 26.9885
# Epoch [1/20], Step [800/12942], Loss: 3.3736, Perplexity: 29.1846
# Epoch [1/20], Step [900/12942], Loss: 3.2742, Perplexity: 26.4223
# Epoch [1/20], Step [1000/12942], Loss: 2.8780, Perplexity: 17.7783
# Epoch [1/20], Step [1100/12942], Loss: 2.5932, Perplexity: 13.3724
# Epoch [1/20], Step [1200/12942], Loss: 2.8938, Perplexity: 18.0614
# Epoch [1/20], Step [1300/12942], Loss: 3.7129, Perplexity: 40.9724
# Epoch [1/20], Step [1400/12942], Loss: 2.7477, Perplexity: 15.6074
# Epoch [1/20], Step [1500/12942], Loss: 2.7179, Perplexity: 15.1488
# Epoch [1/20], Step [1600/12942], Loss: 2.7535, Perplexity: 15.6973
# Epoch [1/20], Step [1700/12942], Loss: 3.1088, Perplexity: 22.3940
# Epoch [1/20], Step [1800/12942], Loss: 2.5745, Perplexity: 13.1252
# Epoch [1/20], Step [1900/12942], Loss: 3.0760, Perplexity: 21.6720
# Epoch [1/20], Step [2000/12942], Loss: 2.8144, Perplexity: 16.6828
# Epoch [1/20], Step [2100/12942], Loss: 3.0521, Perplexity: 21.1593
# Epoch [1/20], Step [2200/12942], Loss: 2.5928, Perplexity: 13.3667
# Epoch [1/20], Step [2300/12942], Loss: 3.9117, Perplexity: 49.9817
# Epoch [1/20], Step [2400/12942], Loss: 2.9202, Perplexity: 18.5458
# Epoch [1/20], Step [2500/12942], Loss: 2.6233, Perplexity: 13.7817
# Epoch [1/20], Step [2600/12942], Loss: 2.6580, Perplexity: 14.2674
# Epoch [1/20], Step [2700/12942], Loss: 2.5324, Perplexity: 12.5835
# Epoch [1/20], Step [2800/12942], Loss: 2.7908, Perplexity: 16.2946
# Epoch [1/20], Step [2900/12942], Loss: 2.5879, Perplexity: 13.3014
# Epoch [1/20], Step [3000/12942], Loss: 2.2569, Perplexity: 9.55304
# Epoch [1/20], Step [3100/12942], Loss: 2.5040, Perplexity: 12.2310
# Epoch [1/20], Step [3200/12942], Loss: 2.3172, Perplexity: 10.1471
# Epoch [1/20], Step [3300/12942], Loss: 2.4948, Perplexity: 12.1192
# Epoch [1/20], Step [3400/12942], Loss: 2.6852, Perplexity: 14.6608
# Epoch [1/20], Step [3500/12942], Loss: 2.5964, Perplexity: 13.4151
# Epoch [1/20], Step [3600/12942], Loss: 2.3873, Perplexity: 10.8836
# Epoch [1/20], Step [3700/12942], Loss: 2.8440, Perplexity: 17.1837
# Epoch [1/20], Step [3800/12942], Loss: 2.5797, Perplexity: 13.1938
# Epoch [1/20], Step [3900/12942], Loss: 3.0037, Perplexity: 20.1610
# Epoch [1/20], Step [4000/12942], Loss: 2.5334, Perplexity: 12.5963
# Epoch [1/20], Step [4100/12942], Loss: 2.3374, Perplexity: 10.3547
# Epoch [1/20], Step [4200/12942], Loss: 2.4258, Perplexity: 11.3117
# Epoch [1/20], Step [4300/12942], Loss: 2.2417, Perplexity: 9.40914
# Epoch [1/20], Step [4400/12942], Loss: 2.2780, Perplexity: 9.75694
# Epoch [1/20], Step [4500/12942], Loss: 2.3419, Perplexity: 10.4011
# Epoch [1/20], Step [4600/12942], Loss: 2.5564, Perplexity: 12.8894
# Epoch [1/20], Step [4700/12942], Loss: 2.5594, Perplexity: 12.9285
# Epoch [1/20], Step [4800/12942], Loss: 2.4511, Perplexity: 11.6014
# Epoch [1/20], Step [4900/12942], Loss: 2.6849, Perplexity: 14.6563
# Epoch [1/20], Step [5000/12942], Loss: 2.0193, Perplexity: 7.532828
# Epoch [1/20], Step [5100/12942], Loss: 2.4171, Perplexity: 11.2134
# Epoch [1/20], Step [5200/12942], Loss: 2.6328, Perplexity: 13.9122
# Epoch [1/20], Step [5300/12942], Loss: 2.5706, Perplexity: 13.0735
# Epoch [1/20], Step [5400/12942], Loss: 2.4779, Perplexity: 11.9158
# Epoch [1/20], Step [5500/12942], Loss: 2.3736, Perplexity: 10.7356
# Epoch [1/20], Step [5600/12942], Loss: 2.9014, Perplexity: 18.2004
# Epoch [1/20], Step [5700/12942], Loss: 2.7884, Perplexity: 16.2550
# Epoch [1/20], Step [5800/12942], Loss: 2.6760, Perplexity: 14.5270
# Epoch [1/20], Step [5900/12942], Loss: 2.1328, Perplexity: 8.43828
# Epoch [1/20], Step [6000/12942], Loss: 2.2792, Perplexity: 9.76921
# Epoch [1/20], Step [6100/12942], Loss: 2.2134, Perplexity: 9.146414
# Epoch [1/20], Step [6200/12942], Loss: 2.4105, Perplexity: 11.1394
# Epoch [1/20], Step [6300/12942], Loss: 2.1812, Perplexity: 8.85658
# Epoch [1/20], Step [6400/12942], Loss: 2.3835, Perplexity: 10.8424
# Epoch [1/20], Step [6500/12942], Loss: 2.1777, Perplexity: 8.82617
# Epoch [1/20], Step [6600/12942], Loss: 2.3431, Perplexity: 10.4134
# Epoch [1/20], Step [6700/12942], Loss: 2.4039, Perplexity: 11.0661
# Epoch [1/20], Step [6800/12942], Loss: 2.3681, Perplexity: 10.6767
# Epoch [1/20], Step [6900/12942], Loss: 2.2336, Perplexity: 9.33334
# Epoch [1/20], Step [7000/12942], Loss: 2.2939, Perplexity: 9.91386
# Epoch [1/20], Step [7100/12942], Loss: 2.3728, Perplexity: 10.7269
# Epoch [1/20], Step [7200/12942], Loss: 2.3798, Perplexity: 10.8027
# Epoch [1/20], Step [7300/12942], Loss: 2.1701, Perplexity: 8.75870
# Epoch [1/20], Step [7400/12942], Loss: 2.2549, Perplexity: 9.53434
# Epoch [1/20], Step [7500/12942], Loss: 2.0808, Perplexity: 8.01122
# Epoch [1/20], Step [7600/12942], Loss: 2.2813, Perplexity: 9.78918
# Epoch [1/20], Step [7700/12942], Loss: 2.3193, Perplexity: 10.1688
# Epoch [1/20], Step [7800/12942], Loss: 2.3250, Perplexity: 10.2264
# Epoch [1/20], Step [7900/12942], Loss: 2.2565, Perplexity: 9.54916
# Epoch [1/20], Step [8000/12942], Loss: 2.5043, Perplexity: 12.2352
# Epoch [1/20], Step [8100/12942], Loss: 2.3080, Perplexity: 10.0546
# Epoch [1/20], Step [8200/12942], Loss: 2.3690, Perplexity: 10.6865
# Epoch [1/20], Step [8300/12942], Loss: 2.3269, Perplexity: 10.2456
# Epoch [1/20], Step [8400/12942], Loss: 2.4989, Perplexity: 12.1686
# Epoch [1/20], Step [8500/12942], Loss: 2.0289, Perplexity: 7.60554
# Epoch [1/20], Step [8600/12942], Loss: 2.3533, Perplexity: 10.5207
# Epoch [1/20], Step [8700/12942], Loss: 2.2622, Perplexity: 9.60414
# Epoch [1/20], Step [8800/12942], Loss: 1.9412, Perplexity: 6.96723
# Epoch [1/20], Step [8900/12942], Loss: 2.1411, Perplexity: 8.50864
# Epoch [1/20], Step [9000/12942], Loss: 2.0666, Perplexity: 7.89772
# Epoch [1/20], Step [9100/12942], Loss: 2.6090, Perplexity: 13.5858
# Epoch [1/20], Step [9200/12942], Loss: 2.1512, Perplexity: 8.59524
# Epoch [1/20], Step [9300/12942], Loss: 2.4307, Perplexity: 11.3663
# Epoch [1/20], Step [9400/12942], Loss: 2.0510, Perplexity: 7.77577
# Epoch [1/20], Step [9500/12942], Loss: 2.4580, Perplexity: 11.6810
# Epoch [1/20], Step [9600/12942], Loss: 2.3098, Perplexity: 10.0722
# Epoch [1/20], Step [9700/12942], Loss: 2.1468, Perplexity: 8.55738
# Epoch [1/20], Step [9800/12942], Loss: 2.1925, Perplexity: 8.95726
# Epoch [1/20], Step [9900/12942], Loss: 2.2755, Perplexity: 9.73278
# Epoch [1/20], Step [10000/12942], Loss: 2.4603, Perplexity: 11.7082
# Epoch [1/20], Step [10100/12942], Loss: 2.5438, Perplexity: 12.7274
# Epoch [1/20], Step [10200/12942], Loss: 2.3575, Perplexity: 10.5649
# Epoch [1/20], Step [10300/12942], Loss: 2.4689, Perplexity: 11.8094
# Epoch [1/20], Step [10400/12942], Loss: 2.1584, Perplexity: 8.65739
# Epoch [1/20], Step [10500/12942], Loss: 2.3284, Perplexity: 10.2620
# Epoch [1/20], Step [10600/12942], Loss: 2.4720, Perplexity: 11.8459
# Epoch [1/20], Step [10700/12942], Loss: 1.9596, Perplexity: 7.09648
# Epoch [1/20], Step [10800/12942], Loss: 2.5190, Perplexity: 12.4165
# Epoch [1/20], Step [10900/12942], Loss: 2.3639, Perplexity: 10.6322
# Epoch [1/20], Step [11000/12942], Loss: 2.1918, Perplexity: 8.95095
# Epoch [1/20], Step [11100/12942], Loss: 2.0382, Perplexity: 7.67677
# Epoch [1/20], Step [11200/12942], Loss: 2.0608, Perplexity: 7.85230
# Epoch [1/20], Step [11300/12942], Loss: 2.5002, Perplexity: 12.1850
# Epoch [1/20], Step [11400/12942], Loss: 2.4767, Perplexity: 11.9020
# Epoch [1/20], Step [11500/12942], Loss: 2.2586, Perplexity: 9.57010
# Epoch [1/20], Step [11600/12942], Loss: 1.9339, Perplexity: 6.91615
# Epoch [1/20], Step [11700/12942], Loss: 2.2179, Perplexity: 9.18808
# Epoch [1/20], Step [11800/12942], Loss: 2.0814, Perplexity: 8.01573
# Epoch [1/20], Step [11900/12942], Loss: 2.2807, Perplexity: 9.78327
# Epoch [1/20], Step [12000/12942], Loss: 2.0911, Perplexity: 8.09349
# Epoch [1/20], Step [12100/12942], Loss: 2.0005, Perplexity: 7.39247
# Epoch [1/20], Step [12200/12942], Loss: 2.1914, Perplexity: 8.94758
# Epoch [1/20], Step [12300/12942], Loss: 2.2359, Perplexity: 9.35513
# Epoch [1/20], Step [12400/12942], Loss: 2.3060, Perplexity: 10.0338
# Epoch [1/20], Step [12500/12942], Loss: 2.2689, Perplexity: 9.66916
# Epoch [1/20], Step [12600/12942], Loss: 2.0870, Perplexity: 8.06095
# Epoch [1/20], Step [12700/12942], Loss: 2.3165, Perplexity: 10.1406
# Epoch [1/20], Step [12800/12942], Loss: 2.4713, Perplexity: 11.8384
# Epoch [1/20], Step [12900/12942], Loss: 2.2259, Perplexity: 9.26160
# Epoch [1/20], Step [12942/12942], Loss: 2.2218, Perplexity: 9.22427
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-87441666f597> in <module>
#      57     # Save the weights.
#      58     if epoch % save_every == 0:
# ---> 59         torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
#      60         torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))
#      61
#
# C:\Anaconda3\envs\cv-nd\lib\site-packages\torch\serialization.py in save(obj, f, pickle_module, pickle_protocol)
#     217         >>> torch.save(x, buffer)
#     218     """
# --> 219     return _with_file_like(f, "wb", lambda f: _save(obj, f, pickle_module, pickle_protocol))
#     220
#     221
#
# C:\Anaconda3\envs\cv-nd\lib\site-packages\torch\serialization.py in _with_file_like(f, mode, body)
#     140             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     141         new_fd = True
# --> 142         f = open(f, mode)
#     143     try:
#     144         return body(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './models\\decoder-1.pkl'

# %%
torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))
